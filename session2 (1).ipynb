# %%
import pandas as pd 
import requests

# %% [markdown]
# to import excel we use pandas and create a dataframe with excel data

# %%
pd.read_excel('C:\\Users\\PC DE JEMARCO\\Desktop\\datascience\\Data-sheet-STUDENTS.xlsx')
# Out:
#    Unnamed: 0                         Indicator #                Unnamed: 2  \
# 0   Country #                       Source link:                        NaN
# 1         NaN      Country (according to CN Gov):  Date of research inquiry
# 2           1                         Afghanistan                       NaN
# 3           2                             Albania                       NaN
# 4           3                             Armenia                       NaN
# 5           4                          Azerbaijan                       NaN
# 6           5                             Bahrain                       NaN
# 7           6                          Bangladesh                       NaN
# 8           7                             Belarus                       NaN
# 9           8                              Bhutan                       NaN
# 10          9              Bosnia and Herzegovina                       NaN
# 11         10                              Brunei                       NaN
# 12         11                            Bulgaria                       NaN
# 13         12                            Cambodia       2018-08-16 00:00:00
# 14         13                               China                       NaN
# 15         14                             Croatia                       NaN
# 16         15                      Czech Republic                       NaN
# 17         16                          East Timor                       NaN
# 18         17                               Egypt                       NaN
# 19         18                             Estonia                       NaN
# 20         19                    France (Not BRI)                       NaN
# 21         20                             Georgia                       NaN
# 22         21                   Germany (not BRI)                       NaN
# 23         22                             Hungary                       NaN
# 24         23                               India                       NaN
# 25         24                           Indonesia                       NaN
# 26         25                                Iran                       NaN
# 27         26                                Iraq                       NaN
# 28         27                              Israel                       NaN
# 29         28                              Jordan                       NaN
# ..        ...                                 ...                       ...
# 40         39                             Moldova                       NaN
# 41         40                            Mongolia                       NaN
# 42         41                          Montenegro                       NaN
# 43         42                             Myanmar                       NaN
# 44         43                               Nepal                       NaN
# 45         44                                Oman                       NaN
# 46         45                            Pakistan                       NaN
# 47         46                         Philippines                       NaN
# 48         47                              Poland                       NaN
# 49         48                               Qatar                       NaN
# 50         49                             Romania                       NaN
# 51         50                              Russia                       NaN
# 52         51                        Saudi Arabia                       NaN
# 53         52                              Serbia                       NaN
# 54         53                           Singapore                       NaN
# 55         54                            Slovakia                       NaN
# 56         55                            Slovenia                       NaN
# 57         56                           Sri Lanka                       NaN
# 58         57                               Syria                       NaN
# 59         58                          Tajikistan                       NaN
# 60         59                           Thailiand                       NaN
# 61         60            The United Arab Emirates                       NaN
# 62         61                              Turkey                       NaN
# 63         62                        Turkmenistan                       NaN
# 64         63            United Kingdom (Not BRI)                       NaN
# 65         64  United States of America (Not BRI)                       NaN
# 66         65                             Ukraine                       NaN
# 67         66                          Uzbekistan                       NaN
# 68         67                             Vietnam                       NaN
# 69         68                               Yemen                       NaN
#
#                                               1  \
# 0               https://www.heritage.org/index/
# 1   HF Index of Economic Freedom (Scale: 1-100)
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                         58.7
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                           37
# 21                                          NaN
# 22                                           34
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# ..                                          ...
# 40                                          NaN
# 41                                          NaN
# 42                                          NaN
# 43                                          NaN
# 44                                          NaN
# 45                                          NaN
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49                                          NaN
# 50                                          NaN
# 51                                          NaN
# 52                                          NaN
# 53                                          NaN
# 54                                          NaN
# 55                                          NaN
# 56                                          NaN
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                           62
# 61                                          NaN
# 62                                          NaN
# 63                                          NaN
# 64                                           55
# 65                                          NaN
# 66                                          NaN
# 67                                          NaN
# 68                                          NaN
# 69                                          NaN
#
#                                                     2  \
# 0                     https://www.heritage.org/index/
# 1   Heritage Foundation Index of Economic Freedom ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                101
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                          3  \
# 0     https://www.bti-project.org/en/home/
# 1   Bertelsmann Transformation index (BTI)
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                       4
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ..                                     ...
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN
# 50                                     NaN
# 51                                     NaN
# 52                                     NaN
# 53                                     NaN
# 54                                     NaN
# 55                                     NaN
# 56                                     NaN
# 57                                     NaN
# 58                                     NaN
# 59                                     NaN
# 60                                     NaN
# 61                                     NaN
# 62                                     NaN
# 63                                     NaN
# 64                                     NaN
# 65                                     NaN
# 66                                     NaN
# 67                                     NaN
# 68                                     NaN
# 69                                     NaN
#
#                                                    4  \
# 0               https://www.bti-project.org/en/home/
# 1   Bertelsmann Transformation index (BTI) - Ranking
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               103
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
# 60                                               NaN
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                               NaN
# 65                                               NaN
# 66                                               NaN
# 67                                               NaN
# 68                                               NaN
# 69                                               NaN
#
#                                                     5  \
# 0   https://data.worldbank.org/indicator/GC.TAX.IM...
# 1   IMF WB\nCustoms and other import duties (% of ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                             15.785
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                     6  \
# 0   https://data.worldbank.org/indicator/FB.AST.NP...
# 1   WB IMF Non-performing loans to total gross loa...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                            0.02072
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                     7  ...  \
# 0   https://globalratings.net/ratings-info/rating-...  ...
# 1                     Moody's Socvereign Ratings List  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                 B2  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                                                NaN  ...
# 18                                                NaN  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24                                                NaN  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27                                                NaN  ...
# 28                                                NaN  ...
# 29                                                NaN  ...
# ..                                                ...  ...
# 40                                                NaN  ...
# 41                                                NaN  ...
# 42                                                NaN  ...
# 43                                                NaN  ...
# 44                                                NaN  ...
# 45                                                NaN  ...
# 46                                                NaN  ...
# 47                                                NaN  ...
# 48                                                NaN  ...
# 49                                                NaN  ...
# 50                                                NaN  ...
# 51                                                NaN  ...
# 52                                                NaN  ...
# 53                                                NaN  ...
# 54                                                NaN  ...
# 55                                                NaN  ...
# 56                                                NaN  ...
# 57                                                NaN  ...
# 58                                                NaN  ...
# 59                                                NaN  ...
# 60                                                NaN  ...
# 61                                                NaN  ...
# 62                                                NaN  ...
# 63                                                NaN  ...
# 64                                                NaN  ...
# 65                                                NaN  ...
# 66                                                NaN  ...
# 67                                                NaN  ...
# 68                                                NaN  ...
# 69                                                NaN  ...
#
#                                                    31  \
# 0           https://eng.yidaiyilu.gov.cn/jcsuce.htm?0
# 1   BRI Percentage of Urban Population in Total Po...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                            0.20723
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                 32  \
# 0                              NaN
# 1   WB Cost of Starting a Business
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                            51.3
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# ..                             ...
# 40                             NaN
# 41                             NaN
# 42                             NaN
# 43                             NaN
# 44                             NaN
# 45                             NaN
# 46                             NaN
# 47                             NaN
# 48                             NaN
# 49                             NaN
# 50                             NaN
# 51                             NaN
# 52                             NaN
# 53                             NaN
# 54                             NaN
# 55                             NaN
# 56                             NaN
# 57                             NaN
# 58                             NaN
# 59                             NaN
# 60                             NaN
# 61                             NaN
# 62                             NaN
# 63                             NaN
# 64                             NaN
# 65                             NaN
# 66                             NaN
# 67                             NaN
# 68                             NaN
# 69                             NaN
#
#                                                    33  \
# 0                                                 NaN
# 1   WB Ease of Doing Business Index (1 = most busi...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                    34  \
# 0                                                 NaN
# 1   WB Logistics Performance Index (LPI) (range: 1...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                               2.58
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                4.2
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                    35  \
# 0   https://data.worldbank.org/indicator/BX.KLT.DI...
# 1                         IFDI Net Inflows (% of GDP)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                             11.426
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                    36  \
# 0   https://yearbook.enerdata.net/electricity/elec...
# 1          ED National Electric Power Consumption TwH
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                    37  \
# 0   https://data.worldbank.org/indicator/SH.XPD.CH...
# 1        WHO Current Health Expenditure p.c., PPP USD
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                            209.617
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                    38  \
# 0   https://data.worldbank.org/indicator/GB.XPD.RS...
# 1                    WB Research Expenditure % of GDP
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                            209.617
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
#
#                                                   39  \
# 0   https://data.worldbank.org/indicator/IP.TMK.RSCT
# 1                        WIPO Trademark applications
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                             1.182
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
# 60                                               NaN
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                               NaN
# 65                                               NaN
# 66                                               NaN
# 67                                               NaN
# 68                                               NaN
# 69                                               NaN
#
#                                                   40
# 0   https://data.worldbank.org/indicator/IP.PAT.RESD
# 1                           WIPO Patent Applications
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                                 0
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
# 60                                               NaN
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                               NaN
# 65                                               NaN
# 66                                               NaN
# 67                                               NaN
# 68                                               NaN
# 69                                               NaN
#
# [70 rows x 44 columns]

# %%
df = pd.read_excel('C:\\Users\\PC DE JEMARCO\\Desktop\\datascience\\Data-sheet-STUDENTS.xlsx',header=2,index_col=0)

# %%
df['Country (according to CN Gov):']
# Out:
# 1                            Afghanistan
# 2                                Albania
# 3                                Armenia
# 4                             Azerbaijan
# 5                                Bahrain
# 6                             Bangladesh
# 7                                Belarus
# 8                                 Bhutan
# 9                 Bosnia and Herzegovina
# 10                                Brunei
# 11                              Bulgaria
# 12                              Cambodia
# 13                                 China
# 14                               Croatia
# 15                        Czech Republic
# 16                            East Timor
# 17                                 Egypt
# 18                               Estonia
# 19                      France (Not BRI)
# 20                               Georgia
# 21                     Germany (not BRI)
# 22                               Hungary
# 23                                 India
# 24                             Indonesia
# 25                                  Iran
# 26                                  Iraq
# 27                                Israel
# 28                                Jordan
# 29                            Kazakhstan
# 30                                Kuwait
#                      ...
# 39                               Moldova
# 40                              Mongolia
# 41                            Montenegro
# 42                               Myanmar
# 43                                 Nepal
# 44                                  Oman
# 45                              Pakistan
# 46                           Philippines
# 47                                Poland
# 48                                 Qatar
# 49                               Romania
# 50                                Russia
# 51                          Saudi Arabia
# 52                                Serbia
# 53                             Singapore
# 54                              Slovakia
# 55                              Slovenia
# 56                             Sri Lanka
# 57                                 Syria
# 58                            Tajikistan
# 59                             Thailiand
# 60              The United Arab Emirates
# 61                                Turkey
# 62                          Turkmenistan
# 63              United Kingdom (Not BRI)
# 64    United States of America (Not BRI)
# 65                               Ukraine
# 66                            Uzbekistan
# 67                               Vietnam
# 68                                 Yemen
# Name: Country (according to CN Gov):, Length: 68, dtype: object

# %% [markdown]
# we use https://restcountries.eu/rest/v2/name/afghanistan to search informations for afghanistan
# tuto for requests https://requests-fr.readthedocs.io/en/latest/

# %%
r = requests.get('https://restcountries.eu/rest/v2/name/afghanistan', auth=('user', 'pass'))

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json;charset=utf-8'

# %%
iso_codes = {}

for index, name in df['Country (according to CN Gov):'].items():
    if name in iso_codes:
        continue
    
    cleaned_name = name.split('(')[0].strip()
    if cleaned_name == 'Thailiand':
        cleaned_name = 'Thailand'
    elif cleaned_name == 'The United Arab Emirates':
        cleaned_name = 'United Arab Emirates'
    
    url = 'https://restcountries.eu/rest/v2/name/' + cleaned_name
    r = requests.get(url)
    if r.status_code == 200:
        data = r.json()
        country_code = data[0]['alpha3Code']
        iso_codes[name] = country_code
    else:
        print('[Error] we cannot get the data, the reason is',r.status_code, r.text)
        print(name, cleaned_name)

# %% [raw]
# iso_codes is an empty dictionnary to get back where we were if there is a problem. Not from the beginning.
# key value dictionnary. If the name is already in it, skip, if not continue

# %% [markdown]
# be carreful if you do to many requests on public services, you could get banned. We dont have the isocodes for 6 countries
# Errors because of spelling mistakes (thailiand, the united arab emirates) and because of '(BRI)'

# %% [markdown]
# split() coupe la chaine de caractère en deux au caractère indiqué
# strip() enleve tt les caractères inutiles au début et à la fin (espace, etc..)

# %%
df['isocode'] = df['Country (according to CN Gov):'].apply(lambda x: iso_codes[x])

# %%
df['isocode']
# Out:
# 1     AFG
# 2     ALB
# 3     ARM
# 4     AZE
# 5     BHR
# 6     BGD
# 7     BLR
# 8     BTN
# 9     BIH
# 10    BRN
# 11    BGR
# 12    KHM
# 13    CHN
# 14    HRV
# 15    CZE
# 16    TLS
# 17    EGY
# 18    EST
# 19    FRA
# 20    GEO
# 21    DEU
# 22    HUN
# 23    IOT
# 24    IDN
# 25    IRN
# 26    IRQ
# 27    ISR
# 28    JOR
# 29    KAZ
# 30    KWT
#      ...
# 39    MDA
# 40    MNG
# 41    MNE
# 42    MMR
# 43    NPL
# 44    OMN
# 45    PAK
# 46    PHL
# 47    POL
# 48    QAT
# 49    ROU
# 50    RUS
# 51    SAU
# 52    SRB
# 53    SGP
# 54    SVK
# 55    SVN
# 56    LKA
# 57    SYR
# 58    TJK
# 59    THA
# 60    ARE
# 61    TUR
# 62    TKM
# 63    GBR
# 64    USA
# 65    UKR
# 66    UZB
# 67    VNM
# 68    YEM
# Name: isocode, Length: 68, dtype: object

# %% [markdown]
# Creation of a new "isocode" column in the excel file with the lambda function

# %%
df[['isocode','Country (according to CN Gov):']]
# Out:
#    isocode      Country (according to CN Gov):
# 1      AFG                         Afghanistan
# 2      ALB                             Albania
# 3      ARM                             Armenia
# 4      AZE                          Azerbaijan
# 5      BHR                             Bahrain
# 6      BGD                          Bangladesh
# 7      BLR                             Belarus
# 8      BTN                              Bhutan
# 9      BIH              Bosnia and Herzegovina
# 10     BRN                              Brunei
# 11     BGR                            Bulgaria
# 12     KHM                            Cambodia
# 13     CHN                               China
# 14     HRV                             Croatia
# 15     CZE                      Czech Republic
# 16     TLS                          East Timor
# 17     EGY                               Egypt
# 18     EST                             Estonia
# 19     FRA                    France (Not BRI)
# 20     GEO                             Georgia
# 21     DEU                   Germany (not BRI)
# 22     HUN                             Hungary
# 23     IOT                               India
# 24     IDN                           Indonesia
# 25     IRN                                Iran
# 26     IRQ                                Iraq
# 27     ISR                              Israel
# 28     JOR                              Jordan
# 29     KAZ                          Kazakhstan
# 30     KWT                              Kuwait
# ..     ...                                 ...
# 39     MDA                             Moldova
# 40     MNG                            Mongolia
# 41     MNE                          Montenegro
# 42     MMR                             Myanmar
# 43     NPL                               Nepal
# 44     OMN                                Oman
# 45     PAK                            Pakistan
# 46     PHL                         Philippines
# 47     POL                              Poland
# 48     QAT                               Qatar
# 49     ROU                             Romania
# 50     RUS                              Russia
# 51     SAU                        Saudi Arabia
# 52     SRB                              Serbia
# 53     SGP                           Singapore
# 54     SVK                            Slovakia
# 55     SVN                            Slovenia
# 56     LKA                           Sri Lanka
# 57     SYR                               Syria
# 58     TJK                          Tajikistan
# 59     THA                           Thailiand
# 60     ARE            The United Arab Emirates
# 61     TUR                              Turkey
# 62     TKM                        Turkmenistan
# 63     GBR            United Kingdom (Not BRI)
# 64     USA  United States of America (Not BRI)
# 65     UKR                             Ukraine
# 66     UZB                          Uzbekistan
# 67     VNM                             Vietnam
# 68     YEM                               Yemen
#
# [68 rows x 2 columns]

# %%
custom_other_duties = {}

for i, iso_codes in df['isocode'].items():
    
   
    url = 'https://api.worldbank.org/v2/en/country/' + iso_codes + '/indicator/GC.TAX.IMPT.ZS?format=json&per_page=20000&source=2&mrv=1'
    r = requests.get(url)
    print (iso_codes)
    if r.status_code == 200:
        data = r.json()
        if len(data) == 2:
            page = data[0]['page']
            if page == 1 :
                taxe = data[1][0]['value']
                custom_other_duties[iso_codes] = taxe
            else:
                print('erreur')
                custom_other_duties[iso_codes] = 'null'
        else:
            print('erreur')
            custom_other_duties[iso_codes] = 'null'
    else:
        custom_other_duties[iso_codes] = 'null'
        print('[Error] we cannot get the data, the reason is',r.status_code, r.text)
        print(iso_codes)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# erreur
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY
# EST
# FRA
# GEO
# DEU
# HUN
# IOT
# erreur
# IDN
# IRN
# IRQ
# ISR
# JOR
# KAZ
# KWT
# KGZ
# LAO
# erreur
# LVA
# LBN
# LTU
# MKD
# MYS
# MDV
# MDA
# MNG
# MNE
# erreur
# MMR
# NPL
# OMN
# erreur
# PAK
# erreur
# PHL
# POL
# QAT
# erreur
# ROU
# RUS
# SAU
# SRB
# SGP
# SVK
# SVN
# LKA
# SYR
# erreur
# TJK
# THA
# ARE
# TUR
# TKM
# erreur
# GBR
# USA
# UKR
# UZB
# VNM
# erreur
# YEM
# erreur

# %%
print(custom_other_duties)
# Out:
# {'AFG': 35.203141190445, 'ALB': 2.21645910864918, 'ARM': 6.27539489392694, 'AZE': 7.57184668387459, 'BHR': 27.3860911270983, 'BGD': 28.9230080455078, 'BLR': 8.20061928730465, 'BTN': 2.84050136682242, 'BIH': 0.000155359665070619, 'BRN': 'null', 'BGR': 0.0688596099634017, 'KHM': 13.542015604973, 'CHN': 3.89434134127694, 'HRV': -0.0376305545169416, 'CZE': 0.819566734190984, 'TLS': 4.77991862435917, 'EGY': 6.8490016570956, 'EST': 0.039428987382724, 'FRA': -0.0232445343314451, 'GEO': 0.757021008880042, 'DEU': 0.0212485657218138, 'HUN': -0.000144686648107121, 'IOT': 'null', 'IDN': 2.56897518332382, 'IRN': 20.6964502542622, 'IRQ': 14.105211130071, 'ISR': 0.962752553897723, 'JOR': 7.00619344737872, 'KAZ': 5.29951905118019, 'KWT': 66.8067226890756, 'KGZ': 17.6152097175161, 'LAO': 'null', 'LVA': 0.0755372366897075, 'LBN': 6.04488095511726, 'LTU': 0.711031058816326, 'MKD': 4.65911362142491, 'MYS': 1.56687280103591, 'MDV': 17.845797817127, 'MDA': 3.42323285739468, 'MNG': 13.5021655958073, 'MNE': 'null', 'MMR': 9.00322150515809, 'NPL': 17.7700383177162, 'OMN': 'null', 'PAK': 'null', 'PHL': 20.3576079552952, 'POL': 0.128545876239141, 'QAT': 'null', 'ROU': 0.035332354395594, 'RUS': 6.21762623104324, 'SAU': 23.0173047901435, 'SRB': 5.06221866137756, 'SGP': 0.0715082520522868, 'SVK': 6.64156553388789e-05, 'SVN': 0.808279997916108, 'LKA': 22.0548905792486, 'SYR': 'null', 'TJK': 15.9437469869174, 'THA': 3.952756587923, 'ARE': 0.381747427685012, 'TUR': 2.50452275929646, 'TKM': 'null', 'GBR': 0.0477474161684688, 'USA': 2.64259418024106, 'UKR': 3.99768085531341, 'UZB': 5.186860136235, 'VNM': 'null', 'YEM': 'null'}
